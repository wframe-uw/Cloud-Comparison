# %%
import pandas as pd
import numpy as np

# %%
# GCP
gcp_compute_src = './data/gcp_compute_costs.csv'
gcp_compute_data = pd.read_csv(gcp_compute_src)

# %%
gcp_compute_data.columns
# Out:
# Index(['region', 'family', 'vm type', 'regional_disk', 'sole_tenant',
#        'nested_virtualization', 'local_ssd', 'cores', 'gpu', 'cpu', 'memory',
#        'network_egress', 'on demand price', 'preemptible price'],
#       dtype='object')

# %%
gcp_compute_data.family.unique()
# Out:
# array(['f1', 'g1', 'n1', 'n2', 'n2d', 'e2', 'c2', 'm1', 'm2', 'a2'],
#       dtype=object)

# %% [markdown]
# #### Clean out unwanted columns

# %%
gcp_compute_data
# Out:
#                   region family         vm type regional_disk  sole_tenant  \
# 0                     us     f1        f1-micro          Null            0
# 1            us-central1     f1        f1-micro          Null            0
# 2               us-east1     f1        f1-micro          Null            0
# 3               us-east4     f1        f1-micro          Null            0
# 4               us-west4     f1        f1-micro          Null            0
# ...                  ...    ...             ...           ...          ...
# 3735           australia     a2  a2-megagpu-16g             1           -1
# 3736  southamerica-east1     a2  a2-megagpu-16g             1           -1
# 3737         asia-south1     a2  a2-megagpu-16g             1           -1
# 3738     asia-southeast2     a2  a2-megagpu-16g             1           -1
# 3739         asia-south2     a2  a2-megagpu-16g             1           -1
#
#       nested_virtualization  local_ssd   cores  gpu               cpu  memory  \
# 0                         0          0  shared    0           ['N/A']     0.6
# 1                         0          0  shared    0           ['N/A']     0.6
# 2                         0          0  shared    0           ['N/A']     0.6
# 3                         0          0  shared    0           ['N/A']     0.6
# 4                         0          0  shared    0           ['N/A']     0.6
# ...                     ...        ...     ...  ...               ...     ...
# 3735                     -1          1      96    1  ['Cascade Lake']  1360.0
# 3736                     -1          1      96    1  ['Cascade Lake']  1360.0
# 3737                     -1          1      96    1  ['Cascade Lake']  1360.0
# 3738                     -1          1      96    1  ['Cascade Lake']  1360.0
# 3739                     -1          1      96    1  ['Cascade Lake']  1360.0
#
#      network_egress on demand price preemptible price
# 0              Null          0.0076            0.0035
# 1              Null          0.0076            0.0035
# 2              Null          0.0076            0.0035
# 3              Null          0.0086           0.00375
# 4              Null          0.0086           0.00375
# ...             ...             ...               ...
# 3735            100               0                 0
# 3736            100               0                 0
# 3737            100               0                 0
# 3738            100               0                 0
# 3739            100               0                 0
#
# [3740 rows x 14 columns]

# %%
df_gcp = gcp_compute_data.drop(columns=['regional_disk','nested_virtualization','regional_disk','network_egress'])

# %% [markdown]
# ### Instance Family

# %%
df_gcp['instance_family'] = np.nan
df_gcp.loc[df_gcp['vm type'].str.contains('standard'), 'instance_family'] = 'General purpose'

df_gcp.loc[df_gcp['vm type'].str.contains('highmem'),  'instance_family'] = 'Memory optimized'
df_gcp.loc[df_gcp['vm type'].str.contains('ultramem'), 'instance_family'] = 'Memory optimized'
df_gcp.loc[df_gcp['vm type'].str.contains('megamem'),  'instance_family'] = 'Memory optimized'
df_gcp.loc[df_gcp['vm type'].str.contains('highcpu'),  'instance_family'] = 'Compute optimized'

df_gcp.loc[df_gcp['vm type'].str.contains('highgpu'),  'instance_family'] = 'GPU optimized'
df_gcp.loc[df_gcp['vm type'].str.contains('megagpu'),  'instance_family'] = 'GPU optimized'

df_gcp.loc[df_gcp['vm type'].str.contains('micro'),    'instance_family'] = 'Shared core'
df_gcp.loc[df_gcp['vm type'].str.contains('small'),    'instance_family'] = 'Shared core'
df_gcp.loc[df_gcp['vm type'].str.contains('medium'),   'instance_family'] = 'Shared core'

df_gcp.instance_family.unique()
# Out:
# array(['Shared core', 'Compute optimized', 'Memory optimized',
#        'General purpose', 'GPU optimized'], dtype=object)

# %% [markdown]
# ### Small Cores

# %%
df_gcp.loc[df_gcp['vm type'].str.contains('micro'),  'cores'] = 0.25
df_gcp.loc[df_gcp['vm type'].str.contains('small'),  'cores'] = 0.5
df_gcp.loc[df_gcp['vm type'].str.contains('medium'), 'cores'] = 1

# %% [markdown]
# ### Clock speed

# %% [markdown]
# Based on: https://cloud.google.com/compute/docs/cpu-platforms
# Should probably process all clock speeds in GCP notebook and then merge here

# %%
df_gcp['clock_speed']=np.nan

# %%
df_gcp.cpu.unique()
# Out:
# array(["['N/A']",
#        "['Skylake', 'Broadwell', 'Haswell', 'Sandy Bridge', 'Ivy Bridge']",
#        "['Cascade Lake']", "['AMD EPYC Rome']",
#        "['Skylake', 'Broadwell', 'Haswell', 'AMD EPYC Rome (coming soon)']",
#        "['Skylake', 'Broadwell E5']", "['Cascade Lake', 'Broadwell E7']"],
#       dtype=object)

# %% [markdown]
# #### Many of the above start with either Skylake or Cascade Lake.  Since they present a range of chips, I'm just going to select one of these two

# %%
cpu_vms = pd.read_csv('./data/gcp.cpu_vm_clock.csv')

# %%
cpu_vms
# Out:
#              cpu  vm  clock
# 0   Cascade Lake  n2    2.8
# 1   Cascade Lake  c2    3.1
# 2   Cascade Lake  m2    2.5
# 3   Cascade Lake  a2    2.2
# 4        Skylake  e2    2.0
# 5        Skylake  m1    2.0
# 6        Skylake  n1    2.0
# 7   Broadwell E7  m1    2.2
# 8   Broadwell E5  e2    2.2
# 9   Broadwell E6  n1    2.2
# 10  Broadwell E7  n1    2.2
# 11       Haswell  n1    2.3
# 12    Ivy Bridge  n1    2.5
# 13  Sandy Bridge  n1    2.6

# %%
cpu_vms = cpu_vms[(cpu_vms.cpu == 'Cascade Lake')|(cpu_vms.cpu == 'Skylake')]

# %%
cpu_vms
# Out:
#             cpu  vm  clock
# 0  Cascade Lake  n2    2.8
# 1  Cascade Lake  c2    3.1
# 2  Cascade Lake  m2    2.5
# 3  Cascade Lake  a2    2.2
# 4       Skylake  e2    2.0
# 5       Skylake  m1    2.0
# 6       Skylake  n1    2.0

# %%
for index, row in cpu_vms.iterrows():
    df_gcp.loc[(df_gcp.cpu.str.contains(row['cpu'])) & (df_gcp.family==row['vm']),'clock_speed'] = row['clock']

# %%
df_gcp.clock_speed.unique()
# Out:
# array([nan, 2. , 2.8, 3.1, 2.5, 2.2])

# %%
df_gcp_drop = df_gcp.drop(columns=['family','cpu','preemptible price'])
df_gcp_drop = df_gcp_drop.rename(columns={'cores':'vcpu'})

# on demand price
## remove nulls
df_gcp_drop = df_gcp_drop.dropna(subset=['on demand price'])
df_gcp_drop = df_gcp_drop[df_gcp_drop['on demand price'] != "Null"]

## > 0
df_gcp_drop['on demand price'] = pd.to_numeric(df_gcp_drop['on demand price'], downcast="float")
df_gcp_drop = df_gcp_drop[df_gcp_drop['on demand price']>0]
df_gcp_drop
# Out:
#                region         vm type  sole_tenant  local_ssd  vcpu  gpu  \
# 0                  us        f1-micro            0          0  0.25    0
# 1         us-central1        f1-micro            0          0  0.25    0
# 2            us-east1        f1-micro            0          0  0.25    0
# 3            us-east4        f1-micro            0          0  0.25    0
# 4            us-west4        f1-micro            0          0  0.25    0
# ...               ...             ...          ...        ...   ...  ...
# 3698  asia-southeast1   a2-highgpu-8g           -1          1    96    1
# 3707      us-central1  a2-megagpu-16g           -1          1    96    1
# 3719     europe-west4  a2-megagpu-16g           -1          1    96    1
# 3731   asia-southeast  a2-megagpu-16g           -1          1    96    1
# 3732  asia-southeast1  a2-megagpu-16g           -1          1    96    1
#
#       memory  on demand price instance_family  clock_speed
# 0        0.6          0.00760     Shared core          NaN
# 1        0.6          0.00760     Shared core          NaN
# 2        0.6          0.00760     Shared core          NaN
# 3        0.6          0.00860     Shared core          NaN
# 4        0.6          0.00860     Shared core          NaN
# ...      ...              ...             ...          ...
# 3698   680.0          7.29758   GPU optimized          2.2
# 3707  1360.0          8.79698   GPU optimized          2.2
# 3719  1360.0          9.68403   GPU optimized          2.2
# 3731  1360.0         10.85126   GPU optimized          2.2
# 3732  1360.0         10.85126   GPU optimized          2.2
#
# [3550 rows x 10 columns]

# %%
df_gcp_drop.sole_tenant.unique()
# Out:
# array([ 0,  1, -1])

# %%
df_gcp_sole = df_gcp_drop.rename(columns={'sole_tenant':'tenancy'})
df_gcp_sole.loc[df_gcp_sole.tenancy == 0,'tenancy'] = 'Shared'
df_gcp_sole.loc[df_gcp_sole.tenancy == 1,'tenancy'] = 'Dedicated'
df_gcp_sole.loc[df_gcp_sole.tenancy == -1,'tenancy'] = 'Shared'
df_gcp_sole
# Out:
#                region         vm type tenancy  local_ssd  vcpu  gpu  memory  \
# 0                  us        f1-micro  Shared          0  0.25    0     0.6
# 1         us-central1        f1-micro  Shared          0  0.25    0     0.6
# 2            us-east1        f1-micro  Shared          0  0.25    0     0.6
# 3            us-east4        f1-micro  Shared          0  0.25    0     0.6
# 4            us-west4        f1-micro  Shared          0  0.25    0     0.6
# ...               ...             ...     ...        ...   ...  ...     ...
# 3698  asia-southeast1   a2-highgpu-8g  Shared          1    96    1   680.0
# 3707      us-central1  a2-megagpu-16g  Shared          1    96    1  1360.0
# 3719     europe-west4  a2-megagpu-16g  Shared          1    96    1  1360.0
# 3731   asia-southeast  a2-megagpu-16g  Shared          1    96    1  1360.0
# 3732  asia-southeast1  a2-megagpu-16g  Shared          1    96    1  1360.0
#
#       on demand price instance_family  clock_speed
# 0             0.00760     Shared core          NaN
# 1             0.00760     Shared core          NaN
# 2             0.00760     Shared core          NaN
# 3             0.00860     Shared core          NaN
# 4             0.00860     Shared core          NaN
# ...               ...             ...          ...
# 3698          7.29758   GPU optimized          2.2
# 3707          8.79698   GPU optimized          2.2
# 3719          9.68403   GPU optimized          2.2
# 3731         10.85126   GPU optimized          2.2
# 3732         10.85126   GPU optimized          2.2
#
# [3550 rows x 10 columns]

# %%
df_gcp_final = df_gcp_sole.rename(columns={'vm type':'instance_type', 'on demand price':'price','region':'location'})
df_gcp_final = df_gcp_final.drop(columns=['gpu'])
df_gcp_final
# Out:
#              location   instance_type tenancy  local_ssd  vcpu  memory  \
# 0                  us        f1-micro  Shared          0  0.25     0.6
# 1         us-central1        f1-micro  Shared          0  0.25     0.6
# 2            us-east1        f1-micro  Shared          0  0.25     0.6
# 3            us-east4        f1-micro  Shared          0  0.25     0.6
# 4            us-west4        f1-micro  Shared          0  0.25     0.6
# ...               ...             ...     ...        ...   ...     ...
# 3698  asia-southeast1   a2-highgpu-8g  Shared          1    96   680.0
# 3707      us-central1  a2-megagpu-16g  Shared          1    96  1360.0
# 3719     europe-west4  a2-megagpu-16g  Shared          1    96  1360.0
# 3731   asia-southeast  a2-megagpu-16g  Shared          1    96  1360.0
# 3732  asia-southeast1  a2-megagpu-16g  Shared          1    96  1360.0
#
#          price instance_family  clock_speed
# 0      0.00760     Shared core          NaN
# 1      0.00760     Shared core          NaN
# 2      0.00760     Shared core          NaN
# 3      0.00860     Shared core          NaN
# 4      0.00860     Shared core          NaN
# ...        ...             ...          ...
# 3698   7.29758   GPU optimized          2.2
# 3707   8.79698   GPU optimized          2.2
# 3719   9.68403   GPU optimized          2.2
# 3731  10.85126   GPU optimized          2.2
# 3732  10.85126   GPU optimized          2.2
#
# [3550 rows x 9 columns]

# %%
df_gcp_final.to_pickle('./data/gcp.compute.xz.pkl', compression='xz')
